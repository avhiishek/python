# %%
a=4
b=3
print("addition {} , sub {} , mul {} , div {} , rem {}" .format(a+b,a-b,a*b,a//b,a%b))
# Out:
# addition 7 , sub 1 , mul 12 , div 1 , rem 1

# %%
a=4
b=3
print(a==b,a<=b,a>=b,a!=b)
# Out:
# False False True True

# %%
a=4

a+=20
print(a)
a-=20
print(a)
a//=2
print(a)
a%=3
print(a)
# Out:
# 24
# 4
# 2
# 2

# %%
#membership operators
str1=[1,2,3]
print(2 in str1)
print(4 not in str1)
print(1 not in str1)
# Out:
# True
# True
# False

# %%
x=3
y=6
print(x&y)
print(x|y)
# Out:
# 2
# 7

# %%
x=[1,2,3]
y=[1,2,3]
z=x
print(x is z)
print(x is y)
print(id(x))
print(id(z))
# Out:
# True
# False
# 135535300217728
# 135535300217728

# %%
a=2
b=4.5
c=2+3j
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
a=3
b=4.6
sum=a+b
print(int(sum))
# Out:
# 7

# %%
x=5
y=3
print(x&y)
# Out:
# 1

# %%
#operator presidency
result=7+7-4*5**6-5+4//2
print(result)
# Out:
# -62489

# %%
result=3+2*2**2
print(result)
# Out:
# 11

# %% [markdown]
# st="hello"
# print(st[2])

# %%
x=15
y=5
result=(x+y)*2
print(result)
# Out:
# 40

# %%
lst=[1,3,4,'sujeeet','yadav']
print(lst[4])
# Out:
# yadav
