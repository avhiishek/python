# %%
print('sujeet')
# Out:
# sujeet

# %%
a=4.56
b=7.456
sum=a+b
print( sum)
# Out:
# 12.016

# %%
a=int(input('enter the value of a :'))
b=int(input('enter the value of b :'))

sum=a+b
print(sum)
print(type(sum))
# Out:
# enter the value of a :0
# enter the value of b :45
# 45.0
# <class 'float'>

# %%
a=int(input('enter the value of a :'))
b=int(input('enter the value of b :'))

div=a/b
print(div)
print(type(div))
# Out:
# enter the value of a :9
# enter the value of b :4
# 2.25
# <class 'float'>

# %%
a=int(input('enter the value of a :'))
b=int(input('enter the value of b :'))

mul=a*b
print(mul)
print(type(mul))
# Out:
# enter the value of a :8
# enter the value of b :5
# 40
# <class 'int'>

# %%
#average of tree number input from user
a=int(input('enter the value of a :'))
b=int(input('enter the value of b :'))
c=int(input('enter the value of c :'))

avg=(a+b+c)/3
print(avg)
print(type(avg))
# Out:
# enter the value of a :45
# enter the value of b :567
# enter the value of c :23
# 211.66666666666666
# <class 'float'>

# %%
#division of two number
a=int(input('enter the value of a :'))
b=int(input('enter the value of b :'))

div=a//b
print(div)
print(type(div))
# Out:
# enter the value of a :5
# enter the value of b :6
# 0
# <class 'int'>

# %%
#PROGRAM TO FIND AREA OF A SQUARE AND PERIMETER
a=int(input('enter the value of a :'))

area=a*a
print("area",area)
print(type(area))
pr=4*a
print("perimeter",pr)
print(type(pr))
# Out:
# enter the value of a :89
# area 7921
# <class 'int'>
# perimeter 356
# <class 'int'>

# %%
#area of rectangle
l=int(input('enter the value of l :'))
b=int(input('enter the value of b :'))

area=l*b
print("area",area)
print(type(area))
# Out:
# enter the value of l :9
# enter the value of b :67
# area 603
# <class 'int'>

# %%
#area of triangle and perimeter
a=int(input('enter the value of a :'))
b=int(input('enter the value of b :'))
c=int(input('enter the value of c :'))

s=(a+b+c)/2
area=(s*(s-a)*(s-b)*(s-c))**0.5
print("area",area)
print(type(area))
print("perimeter", s*2)
print(type(s))
# Out:
# enter the value of a :89
# enter the value of b :67
# enter the value of c :89
# area 2762.2268530118954
# <class 'float'>
# perimeter 245.0
# <class 'float'>

# %%
#area of circle
r=int(input('enter the value of r :'))

area=3.14*r*r
print("area",area)
print(type(area))
# Out:
# enter the value of r :9
# area 254.34
# <class 'float'>

# %%
#to calculate the simple interest
p=int(input("enter the value of p :"))
r=int(input("enter the value of r :"))
t=int(input("enter the value of t :"))

si=(p*r*t)/100
print("simple interest",si)
print(type(si))
# Out:
# enter the value of p :10000
# enter the value of r :4
# enter the value of t :2
# simple interest 800.0
# <class 'float'>

# %%
#to calculate the compound interest
p=int(input("enter the value of p :"))
r=int(input("enter the value of r :"))
t=int(input("enter the value of t :"))
compound=(p*(1+(r/100))**t)-p
print("compound interest",compound)
print(type(compound))
# Out:
# enter the value of p :8000
# enter the value of r :5
# enter the value of t :3
# compound interest 1261.0000000000018
# <class 'float'>

# %%
m1=int(input("enter the marks 1 :"))
m2=int(input("enter the marks 2 :"))
m3=int(input("enter the marks 3 :"))
m4=int(input("enter the marks 4 :"))
m5=int(input("enter the marks 5 :"))
marksobtained=(m1+m2+m3+m4+m5)
totalmarks=500
percentage=(marksobtained/totalmarks)*100
print("marks obtained",marksobtained)

print("percantage", percentage)
print(type(marksobtained))
# Out:
# enter the marks 1 :90
# enter the marks 2 :80
# enter the marks 3 :89
# enter the marks 4 :75
# enter the marks 5 :78
# marks obtained 412
# percantage 82.39999999999999
# <class 'int'>

# %%
a=int(input("enter the value of a:"))
b=int(input("enter the value of b :"))




print(a*b/a,b*a/b)
# Out:
# enter the value of a:9
# enter the value of b :8
# 8.0 9.0

# %%
# different way to print (by using fprint)

age=35
name="sujeet"
print(f"my name is {name} ahir and my age is {age}")
# Out:
# my name is sujeet ahir and my age is 35

# %%
name='sujeet'
age=75
collegename='niet'
print(f"my name is {name} and age is {age} and my college name is {collegename}")
# Out:
# mmy name is sujeet and age is 75 and my college name is niet

# %%
#print using .format method

age=20
name="sujeet"
print("my name is {} and age is {}".format(name,age))
# Out:
# my name is sujeet and age is 20

# %%
num=91.457357
print(f"print on 2 decimal point{num:.8f}")
# Out:
# print on 2 decimal point91.45735700

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
name='sujeet'
age=25
print(name, age,sep=',')
# Out:
# sujeet,25

# %%
print('a','b','c',sep='#')
# Out:
# a#b#c

# %%
print('1','2','3','4','5', sep=",")
# Out:
# 1,2,3,4,5

# %%
name='sujeet'
lastname= "yadav"
print(name +" "+ lastname)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-caa545947899> in <cell line: 0>()
#       1 name='sujeet'
#       2 lastname= "yadav"
# ----> 3 print(name +" "+ lastname)
#
# TypeError: 'str' object is not callable

# %%
_name="sujeet"
print(_name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-149be46f6eff> in <cell line: 0>()
#       1 _name="sujeet"
# ----> 2 print(_name)
#
# TypeError: 'str' object is not callable
